# %% [markdown]
# ### Question -1

# %%
a = int(input())
b = int(input())
choice  = int(input())

### Do the operations here

if choice ==1:
    summ = a +b
    print('The sum of 2 numbers a and b is :',summ)
elif choice ==2:
    sub = a-b
    print('The difference between 2 numbers is :',diff)
elif choice ==3:
    mult = a *b
    print('Product of 2 numbers are :',a*b)
elif choice ==4:
    div = a/b
    print('The divison of a and b gives you :',a/b)
else:
    print('Invalid Operation')
# Out:
# 1
# 2
# 4
# The divison of a and b gives you : 0.5

# %% [markdown]
# ### Question -2

# %%
x = 24
y = '12'
z = y/x
print(x, z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cf35782aa381> in <module>
#       1 x = 24
#       2 y = '12'
# ----> 3 z = y/x
#       4 print(x, z)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# #### Takeaway : We cant divide a number with a string

# %% [markdown]
# ### Question -3

# %% [markdown]
# #### To check the data types of any variable, use type() command

# %%
x1 = 123
type(x1)
# Out:
# int

# %%
x2 = 123.0
type(x2)
# Out:
# float

# %%
x3 = '123.0'
type(x3)
# Out:
# str

# %%
x4 = [123]
type(x4)
# Out:
# list

# %% [markdown]
# ### Question -4

# %%
x = 2345
print('Convert x to float number',float(x))
# Out:
# Convert x to float number 2345.0

# %%
x = str(x)
print('Convert x to a string',x)
# Out:
# Convert x to a string 2345

# %%
print('Now convert part-b which is x to integer')
x = int(x)
print(x)
print(type(x))
# Out:
# Now convert part-b which is x to integer
# 2345
# <class 'int'>

# %% [markdown]
# ### Question-5

# %%
x= 'I am student at NYU'
x = x.split()
print(x)
new_sentence = ''
for i in x:
    new_sentence = new_sentence + i.capitalize() +' '
print(new_sentence)
# Out:
# ['I', 'am', 'student', 'at', 'NYU']
# I Am Student At Nyu

# %% [markdown]
# #### Takeaway : Use .capitalize() to make the first character of each word in CAPS

# %% [markdown]
# ### Question-6

# %%
2>=0
# Out:
# True

# %%
2>=2
# Out:
# True

# %%
2>2
# Out:
# False

# %%
123==123
# Out:
# True

# %%
12==12.0
# Out:
# True

# %%
'Stern' =='STERN'
# Out:
# False

# %%
3>=0 or 1<=2
# Out:
# True

# %%
3>=0 and 1<=2
# Out:
# True

# %% [markdown]
# #### Takeaway : Notice how the boolean operations works

# %% [markdown]
# ### Question -7

# %%
x = [1, 2, 3, 4, 'Dealing',5,6,'with',7,'Data',8,9,'NYU']

# %%
print('First element of x is :',x[0])
# Out:
# First element of x is : 1

# %%
print('Last element of x is :',x[-1])
# Out:
# Last element of x is : NYU

# %%
print('All except the last element :',x[:-1])
# Out:
# All except the last element : [1, 2, 3, 4, 'Dealing', 5, 6, 'with', 7, 'Data', 8, 9]

# %% [markdown]
# ### Question -8

# %%
Sentence = "I am a student at NYU Stern"
Sentence.split()
# Out:
# ['I', 'am', 'a', 'student', 'at', 'NYU', 'Stern']

# %% [markdown]
# #### Takeaway : Use .split() to slice out the complete sentence

# %% [markdown]
# ### Question-9

# %%
x= [1, 2, "a", 'b', "NYU", "Stern", 3, "Data", 'Dealing', 10]

# %%
print('First element is :',x[0])
# Out:
# First element is : 1

# %%
print('Last element is :',x[-1])
# Out:
# Last element is : 10

# %%
print("Slice from 'a' to 10 is :",x[2:])
# Out:
# Slice from 'a' to 10 is : ['a', 'b', 'NYU', 'Stern', 3, 'Data', 'Dealing', 10]

# %%
print('Printing every element on a new line :----')

for i in x:
    print(i)
# Out:
# Printing every element on a new line :----
# 1
# 2
# a
# b
# NYU
# Stern
# 3
# Data
# Dealing
# 10

# %%
print('Writing a loop where only type string elements would be printed')
for i in x:
    if type(i) ==str:
        print(i)
# Out:
# Writing a loop where only type string elements would be printed
# a
# b
# NYU
# Stern
# Data
# Dealing

# %% [markdown]
# ### Question -10

# %%
first = "Alexander"
last = "The#Great"

# %%
print('First letter from is :',last[0])
# Out:
# First letter from is : T

# %%
print('Splitting the last into 2 components')
last.split('#')
# Out:
# Splitting the last into 2 components
# ['The', 'Great']

# %%
new_name = first +' '+ last[0] +'.'
print(new_name)
# Out:
# Alexander T.

# %% [markdown]
# #### Takeaway : Splitting can be also done on '#'
