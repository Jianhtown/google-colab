# %% [markdown]
# ## To submit this assignment, please solve the following problem. Then, save your notebook with the format [YOUR_NAME_HERE]\_Class3_Homework and submit via NYU Classes.

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 1 (5 points):
# Write a program that creates a shopping list of at least 5 items using user input.
#
# > 2 points: The user must be able to add to the list and view the updated list as a comma-separated group of items after adding to it.
#
# > 2 points: the user must be able to remove items from the list and view the updated list as a comma-separated group of items after removing something from it
#
# > 1 point: the user must be able to tell the program to end

# %%
# your code here
my_list = []
print("add the 1st item into the list")
my_list.append(input())
print("add the 2nd item into the list")
my_list.append(input())
print("add the 3rd item into the list")
my_list.append(input())
print("add the 4th item into the list")
my_list.append(input())
print("add the 5th item into the list")
my_list.append(input())
# items = input().lower.split(",")
print(my_list)

print("do you want to add or remove or just end?")
command = input()
if command == "end":
  print("ended")
elif command == "add":
  print("what do you want to add")
  my_list.append(input())
  print(my_list)
elif command == "remove":
  print("what is the index of element to remove?")
  index = int(input())
  my_list.pop(index)
  print("after removing it, the result is: ", my_list)
else:
  print("wrong command")
# Out:
# add the 1st item into the list
# 1
# add the 2nd item into the list
# 2
# add the 3rd item into the list
# 4
# add the 4th item into the list
# 5
# add the 5th item into the list
# 8
# ['1', '2', '4', '5', '8']
# do you want to add or remove or just end?
# remove
# what is the index of element to remove?
# 2
# after removing it, the result is:  ['1', '2', '5', '8']

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 2 (2 points):
#
# #### Choose your own homework adventure - answer ONE of the following questions completely.
#
# (No additional points for extra answers.)
#
# > ##### Question 1: Explain the difference between a `list`, a `tuple` and a `set`. Provide a real-world example where it would be more appropriate to use a `list` to store data as compared to a `tuple` or a `set` (comparing to one is good enough).
#
# > ##### Question 2: Explain the different between a `dictionary` and a `list`. Provide an real-world example where it would be more appropriate to use a `dictionary` to store data as compared to a `list`.

# %% [markdown]
# \> (your answer here)
# All of them can store elements seperated by comma.
# List is ordered, allows duplicates and different types. You can perform complex instructions to change the content of list.
# Tuple is like list but ordered at given length and immutable.
# Set is unordered and does not allows duplicates.
#
# We can perform matrix multiplications on lists of [1,2,3] and [1,1,1]T. But we cannot do that on set cause [1,1,1] has the same element 1.

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 3 (3 points):
#
# Create a nested data structure to store fake data for a real-world use case that is NOT an example we covered in class.
#
# It must have a minimum of one nested structure, such as our in-class phone number example where a `list` was nested within a `dictionary`.
#
# Print values from each part of the nested structure separately. Describe what each nested level is doing using comments.

# %%
# your code here
NBA = {
    "good_teams": {
        "houston_rockets": ["harden","westbrook"], 
        "la_lackers": ["lebron","ad"]},
    "trash_teams":{
        "new_york_knicks": ["nobody1","nobody2"],
        "timberwolves": ["cat"]
    }
}
NBA
# Out:
# {'good_teams': {'houston_rockets': ['harden', 'westbrook'],
#   'la_lackers': ['lebron', 'ad']},
#  'trash_teams': {'new_york_knicks': ['nobody1', 'nobody2'],
#   'timberwolves': ['cat']}}
